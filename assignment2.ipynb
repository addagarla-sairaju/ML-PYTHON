# %% [markdown]
# <a href="https://colab.research.google.com/github/addagarla-sairaju/ML-PYTHON/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ASSIGNMENT2

# %% [markdown]
# ### Create a Pandas DataFrame from the following dictionary:
# data = {
#  'Name': ['Alice', 'Bob', 'Carol'],
#  'Age': [24, 27, 22],
#  'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary

# %%
import pandas as pd
data={
     'Name':['Alice', 'Bob', 'Carol'],
     'Age':[24, 27, 22],
     'Salary':[50000, 55000, 48000] }
df=pd.DataFrame(data)
df['Bonus']=df['Salary'] * 0.10
print(df)
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# ###2. Given the DataFrame created in the above question:
# • Display the first two rows.
# • Compute the mean salary.

# %%
df.head(2)
esalary = df['Salary'].mean()
esalary
# Out:
# 51000.0

# %% [markdown]
# ###3. Using the same DataFrame:
# • Extract all rows where the Age is greater than 25.
# • Filter out rows where the Salary is less than 50000.

# %%
afilter = df[df['Age'] > 25]
sfilter = df[df['Salary'] >= 50000]
print("age >25:\n",afilter)
print("salary>50000:\n",sfilter)
afilter
sfilter
# Out:
# age >25:
#    Name  Age  Salary   Bonus
# 1  Bob   27   55000  5500.0
# salary>50000:
#      Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %% [markdown]
# ###4. Create the following DataFrame:
# data = {
#  'A': [1, 2, None, 4],
#  'B': [None, 2, 3, None],
#  'C': [1, 2, 3, 4]
# }
# df = pd.DataFrame(data)
# • Fill missing values in column A with the mean of the column.
# • Drop rows where all values are None.

# %%
data={
    'A':[1, 2, None, 4],
    'B':[None, 2, 3, None],
    'C':[1, 2, 3, 4]
}
df1=pd.DataFrame(data)
df1['A']=df1['A'].fillna(df1['A'].mean())
cleaned = df1.dropna(how='all')
cleaned
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# ###5. Create a DataFrame for employees:
# data = {
#  'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#  'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#  'Salary': [50000, 45000, 60000, 65000, 70000]
# }
# • Group the data by Department and compute the total and mean salary for each
# department

# %%
data={
    'Department':['HR','HR','IT','IT', 'Finance'],
    'Employee':['Alice','Bob','Carol','David','Eve'],
    'Salary':[50000,45000,60000,65000,70000]
}
employeedf=pd.DataFrame(data)
salary=employeedf.groupby('Department')['Salary'].agg(['sum', 'mean'])
salary
# Out:
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
#  ### 6.Given two DataFrames:
# df1=pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# df2=pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# • Perform an inner join on the ID column.

# %%
df1=pd.DataFrame({'ID':[1,2,3],'Name':['Alice','Bob','Carol']})
df2=pd.DataFrame({'ID':[2,3,4], 'Age':[25, 30, 22]})
df=pd.merge(df1,df2,on='ID',how='inner')
df
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# ### 7. Given a small dataset, clean and display basic statistics using Pandas.

# %%
import pandas as pd
data={
    'Name':['Alice','Bob','Carol',None,'Eve'],
    'Age':[24,27,None,22,25],
    'Salary':[50000,None,48000,52000,60000]
}
df=pd.DataFrame(data)
cleaned=df.fillna({'Age': df['Age'].mean(), 'Salary'  :df['Salary'].mean()})
basic=cleaned.describe()
basic
# Out:
#              Age       Salary
# count   5.000000      5.00000
# mean   24.500000  52500.00000
# std     1.802776   4555.21679
# min    22.000000  48000.00000
# 25%    24.000000  50000.00000
# 50%    24.500000  52000.00000
# 75%    25.000000  52500.00000
# max    27.000000  60000.00000

# %% [markdown]
# ###8. small EDA task
# • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# • Perform the following tasks:
# o Display the number of missing values in each column.
# o Find the average age of passengers.
# o Create a bar plot to show the survival rate based on gender

# %%
import matplotlib.pyplot as plt
df=pd.read_csv('Titanic-Dataset.csv')
missing=df.isnull().sum()
average_age=df['Age'].mean()
survival_gender =df.groupby('Sex')['Survived'].mean()
survival_gender.plot(kind='bar', title='Survival Rate Based on Gender')
plt.ylabel('Survival Rate')
plt.show()
missing, average_age,survival_gender
# Out:
# (PassengerId      0
#  Survived         0
#  Pclass           0
#  Name             0
#  Sex              0
#  Age            177
#  SibSp            0
#  Parch            0
#  Ticket           0
#  Fare             0
#  Cabin          687
#  Embarked         2
#  dtype: int64,
#  29.69911764705882,
#  Sex
#  female    0.742038
#  male      0.188908
#  Name: Survived, dtype: float64)

# %% [markdown]
# ###9. Data Transformation
# • Load a dataset containing daily temperatures and dates. Perform the following:
# o Convert the date column into a DateTime object.
# o Create a new column that categorizes temperatures into High, Medium, or
# Low.

# %%
data={
    'Date':['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04'],
    'Temperature':[30, 15, 20, 25]
}
df=pd.DataFrame(data)
df['Date']=pd.to_datetime(df['Date'])
df['Temp_Category']=pd.cut(df['Temperature'],bins=[0, 15, 25, 40],labels=['Low', 'Medium', 'High'])
df
# Out:
#         Date  Temperature Temp_Category
# 0 2024-01-01           30          High
# 1 2024-01-02           15           Low
# 2 2024-01-03           20        Medium
# 3 2024-01-04           25        Medium
